# %% [markdown]
# In this lab we're going to do simple data exploration using Pandas. Our objective is to learn basic operations that aid in visual data exploration.
#
# <br>
#
# First, let's import our required libraries and read in the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os


cwd = os.getcwd()

#If on MAC, this will likely work
datadir = '/'.join(cwd.split('/')[0:-1]) + '/data/'
#If on window's machine, explicitly put in data dir
#datadir = 

# %matplotlib inline


#Now read in the dataset loansdata.csv
loansData = pd.read_csv('/Users/angelateng/Documents/GitHub/DataScienceCourse/ipython/data/loansData.csv')

# %%
loansData
# Out:
#       CustNUm  Amount.Requested  Amount.Funded.By.Investors Interest.Rate  \
# 0       81174             20000                    20000.00         8.90%
# 1       99592             19200                    19200.00        12.12%
# 2       80059             35000                    35000.00        21.98%
# 3       15825             10000                     9975.00         9.99%
# 4       33182             12000                    12000.00        11.71%
# 5       62403              6000                     6000.00        15.31%
# 6       48808             10000                    10000.00         7.90%
# 7       22090             33500                    33450.00        17.14%
# 8       76404             14675                    14675.00        14.33%
# 9       15867              7000                     7000.00         6.91%
# 10      94971              2000                     2000.00        19.72%
# 11      36911             10625                    10625.00        14.27%
# 12      41200             28000                    27975.00        21.67%
# 13      83869             35000                    34950.00         8.90%
# 14      53853              9600                     9600.00         7.62%
# 15      21399             25000                    24975.00        15.65%
# 16      62127             10000                    10000.00        12.12%
# 17      23446             14000                    13900.25        10.37%
# 18      44987             10000                    10000.00         9.76%
# 19      17977              5200                     5175.00         9.99%
# 20      86099             22000                    21975.00        21.98%
# 21      99483             30000                    30000.00        19.05%
# 22      28798              6500                     6500.00        17.99%
# 23      24168             17400                    17400.00        11.99%
# 24      10356              4000                     4000.00        16.82%
# 25      46027              7200                     7200.00         7.90%
# 26       2238              8000                     8000.00        14.42%
# 27      65278              8000                     8000.00        15.31%
# 28       4227              3000                     3000.00         8.59%
# 29      50182             14500                    14500.00         7.90%
# ...       ...               ...                         ...           ...
# 2470    84265             20000                    20000.00        22.95%
# 2471    80231             19000                    19000.00         7.90%
# 2472    49533             17300                    17250.00        22.45%
# 2473   102514              7000                      711.54        15.13%
# 2474    78618              7200                     7200.00        18.75%
# 2475    86953             10000                    10000.00        14.09%
# 2476    80129              4000                     3925.00        14.09%
# 2477    85216             17500                    17500.00         8.90%
# 2478    38247             20000                    20000.00        11.71%
# 2479    91245             16200                    16200.00        15.80%
# 2480    53041             10000                    10000.00         6.03%
# 2481    63051             27000                    27000.00         6.62%
# 2482    14446              4500                     4475.00         7.51%
# 2483    68628             15875                    15875.00        14.33%
# 2484    98758             15000                    15000.00        10.16%
# 2485    13070             25000                    24950.00        10.75%
# 2486    45836              7000                     7000.00        17.27%
# 2487    52330             15000                    15000.00        19.99%
# 2488    48243             17000                    17000.00        15.81%
# 2489    63256             19075                    19075.00        18.75%
# 2490    42124             10000                    10000.00        11.71%
# 2491    78043              8475                     8475.00         7.62%
# 2492      925              6400                     6350.00        10.08%
# 2493    74047             30000                    30000.00        23.28%
# 2494    49957             24000                    23975.00        14.65%
# 2495    23735             30000                    29950.00        16.77%
# 2496    65882             16000                    16000.00        14.09%
# 2497    55610             10000                    10000.00        13.99%
# 2498    38576              6000                     6000.00        12.42%
# 2499     3116              9000                     5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# 0      36 months  debt_consolidation               14.90%    SC
# 1      36 months  debt_consolidation               28.36%    TX
# 2      60 months  debt_consolidation               23.81%    CA
# 3      36 months  debt_consolidation               14.30%    KS
# 4      36 months         credit_card               18.78%    NJ
# 5      36 months               other               20.05%    CT
# 6      36 months  debt_consolidation               26.09%    MA
# 7      60 months         credit_card               14.70%    LA
# 8      36 months         credit_card               26.92%    CA
# 9      36 months         credit_card                7.10%    CA
# 10     36 months              moving               10.29%    FL
# 11     36 months  debt_consolidation               12.54%    CA
# 12     60 months  debt_consolidation               13.07%    CT
# 13     36 months  debt_consolidation               20.46%    CT
# 14     36 months  debt_consolidation                3.45%    DC
# 15     60 months  debt_consolidation               21.99%    CA
# 16     36 months  debt_consolidation               17.72%    CA
# 17     60 months  debt_consolidation               11.95%    OH
# 18     36 months         credit_card                7.13%    FL
# 19     60 months  debt_consolidation               10.29%    AL
# 20     36 months  debt_consolidation               11.19%    TX
# 21     60 months         credit_card               21.25%    FL
# 22     60 months                 car               19.63%    FL
# 23     36 months         credit_card               12.47%    AZ
# 24     60 months            vacation               13.71%    GA
# 25     36 months  debt_consolidation               24.82%    TX
# 26     36 months  debt_consolidation               24.63%    MA
# 27     36 months  debt_consolidation               15.46%    CA
# 28     36 months               other                3.72%    MA
# 29     36 months  debt_consolidation                4.85%    GA
# ...          ...                 ...                  ...   ...
# 2470   60 months  debt_consolidation                7.10%    NJ
# 2471   36 months  debt_consolidation                9.76%    RI
# 2472   60 months             wedding                3.58%    PA
# 2473   36 months      major_purchase               18.91%    CO
# 2474   36 months  debt_consolidation               16.21%    MI
# 2475   36 months      major_purchase                9.71%    CO
# 2476   36 months         credit_card               12.27%    FL
# 2477   36 months  debt_consolidation               10.94%    UT
# 2478   36 months         credit_card                9.58%    SD
# 2479   60 months  debt_consolidation                7.92%    PA
# 2480   36 months      small_business               13.03%    FL
# 2481   36 months  debt_consolidation               12.21%    OH
# 2482   36 months      small_business               20.27%    VA
# 2483   36 months      small_business               17.44%    MD
# 2484   36 months         credit_card               28.28%    OH
# 2485   36 months  debt_consolidation               20.48%    OR
# 2486   36 months               other               18.38%    NY
# 2487   36 months             wedding               18.05%    CA
# 2488   36 months  debt_consolidation               17.01%    CO
# 2489   36 months  debt_consolidation               15.23%    NY
# 2490   36 months  debt_consolidation                8.40%    CA
# 2491   36 months  debt_consolidation               15.88%    CA
# 2492   36 months  debt_consolidation                8.11%    NJ
# 2493   60 months               other               12.10%    IL
# 2494   36 months  debt_consolidation               15.29%    WA
# 2495   60 months  debt_consolidation               19.23%    NY
# 2496   60 months    home_improvement               21.54%    MD
# 2497   36 months  debt_consolidation                4.89%    PA
# 2498   36 months      major_purchase               16.66%    NJ
# 2499   36 months  debt_consolidation                6.76%    NY
#
#      Home.Ownership  Monthly.Income FICO.Range  Open.CREDIT.Lines  \
# 0          MORTGAGE         6541.67    735-739               14.0
# 1          MORTGAGE         4583.33    715-719               12.0
# 2          MORTGAGE        11500.00    690-694               14.0
# 3          MORTGAGE         3833.33    695-699               10.0
# 4              RENT         3195.00    695-699               11.0
# 5               OWN         4891.67    670-674               17.0
# 6              RENT         2916.67    720-724               10.0
# 7          MORTGAGE        13863.42    705-709               12.0
# 8              RENT         3150.00    685-689                9.0
# 9              RENT         5000.00    715-719                8.0
# 10             RENT         3575.00    670-674               10.0
# 11         MORTGAGE         4250.00    665-669               14.0
# 12         MORTGAGE        14166.67    670-674               12.0
# 13             RENT         9166.67    735-739               19.0
# 14             RENT        11250.00    725-729               13.0
# 15             RENT         5416.67    730-734                6.0
# 16             RENT         9000.00    695-699               18.0
# 17             RENT         4333.33    740-744                6.0
# 18             RENT         2733.33    730-734                7.0
# 19         MORTGAGE         3750.00    760-764               10.0
# 20         MORTGAGE         6666.67    665-669                9.0
# 21         MORTGAGE         6250.00    695-699               12.0
# 22             RENT         4100.00    665-669               11.0
# 23             RENT         6833.33    695-699                7.0
# 24         MORTGAGE         4500.00    670-674                5.0
# 25             RENT         5416.67    705-709                8.0
# 26             RENT         2964.17    675-679                9.0
# 27         MORTGAGE         2916.67    675-679               13.0
# 28         MORTGAGE         4167.00    765-769                4.0
# 29         MORTGAGE         3958.33    760-764                4.0
# ...             ...             ...        ...                ...
# 2470           RENT         6750.00    665-669                6.0
# 2471       MORTGAGE         5166.67    770-774               18.0
# 2472       MORTGAGE         5500.00    685-689               11.0
# 2473       MORTGAGE         3833.00    650-654               13.0
# 2474           RENT         8333.33    660-664                8.0
# 2475           RENT         4583.33    675-679                6.0
# 2476       MORTGAGE         8583.33    675-679                9.0
# 2477       MORTGAGE        25000.00    730-734                9.0
# 2478       MORTGAGE         5416.67    725-729               12.0
# 2479       MORTGAGE         4833.33    680-684               12.0
# 2480           RENT         5000.00    760-764                8.0
# 2481       MORTGAGE         9250.00    810-814               12.0
# 2482       MORTGAGE         7075.50    720-724               15.0
# 2483       MORTGAGE         3416.67    675-679               11.0
# 2484       MORTGAGE         6666.67    690-694               15.0
# 2485       MORTGAGE         7083.33    765-769               10.0
# 2486            OWN         2464.37    665-669                9.0
# 2487           RENT         8000.00    660-664                6.0
# 2488           RENT         3833.33    685-689                6.0
# 2489           RENT         5166.67    670-674               17.0
# 2490           RENT         4500.00    710-714                8.0
# 2491           RENT         3983.33    720-724                9.0
# 2492       MORTGAGE         5166.67    710-714                5.0
# 2493       MORTGAGE         7083.33    675-679               16.0
# 2494       MORTGAGE         6666.67    685-689               13.0
# 2495       MORTGAGE         9250.00    705-709               15.0
# 2496            OWN         8903.25    740-744               18.0
# 2497       MORTGAGE         2166.67    680-684                4.0
# 2498           RENT         3500.00    675-679                8.0
# 2499           RENT         3875.00    670-674                7.0
#
#       Revolving.CREDIT.Balance  Inquiries.in.the.Last.6.Months  \
# 0                      14272.0                             2.0
# 1                      11140.0                             1.0
# 2                      21977.0                             1.0
# 3                       9346.0                             0.0
# 4                      14469.0                             0.0
# 5                      10391.0                             2.0
# 6                      15957.0                             0.0
# 7                      27874.0                             0.0
# 8                       7246.0                             1.0
# 9                       7612.0                             0.0
# 10                     12036.0                             0.0
# 11                     10767.0                             0.0
# 12                     10311.0                             0.0
# 13                     21536.0                             0.0
# 14                      4606.0                             0.0
# 15                     13929.0                             0.0
# 16                     20317.0                             0.0
# 17                      7419.0                             0.0
# 18                      6112.0                             2.0
# 19                     16094.0                             0.0
# 20                     23124.0                             0.0
# 21                     34927.0                             0.0
# 22                     11697.0                             1.0
# 23                     26587.0                             0.0
# 24                     20804.0                             0.0
# 25                     12017.0                             0.0
# 26                      8928.0                             2.0
# 27                      7152.0                             1.0
# 28                      7074.0                             0.0
# 29                      9598.0                             0.0
# ...                        ...                             ...
# 2470                   16104.0                             1.0
# 2471                   43617.0                             2.0
# 2472                    2306.0                             3.0
# 2473                   12634.0                             0.0
# 2474                   28916.0                             0.0
# 2475                    3859.0                             0.0
# 2476                   36943.0                             1.0
# 2477                   34545.0                             0.0
# 2478                   18267.0                             1.0
# 2479                   12313.0                             2.0
# 2480                    3952.0                             0.0
# 2481                    4211.0                             0.0
# 2482                   68618.0                             2.0
# 2483                   15891.0                             0.0
# 2484                   14880.0                             0.0
# 2485                   25429.0                             0.0
# 2486                    7089.0                             0.0
# 2487                   45976.0                             1.0
# 2488                   15484.0                             1.0
# 2489                   13749.0                             3.0
# 2490                    8404.0                             1.0
# 2491                    6882.0                             0.0
# 2492                    5815.0                             2.0
# 2493                   17969.0                             1.0
# 2494                   17521.0                             0.0
# 2495                   45880.0                             1.0
# 2496                   18898.0                             1.0
# 2497                    4544.0                             0.0
# 2498                    7753.0                             0.0
# 2499                    7589.0                             0.0
#
#      Employment.Length
# 0             < 1 year
# 1              2 years
# 2              2 years
# 3              5 years
# 4              9 years
# 5              3 years
# 6            10+ years
# 7            10+ years
# 8              8 years
# 9              3 years
# 10             6 years
# 11            < 1 year
# 12              1 year
# 13              1 year
# 14            < 1 year
# 15             9 years
# 16             7 years
# 17             9 years
# 18             3 years
# 19            < 1 year
# 20           10+ years
# 21             6 years
# 22             2 years
# 23             7 years
# 24             3 years
# 25             7 years
# 26             6 years
# 27             5 years
# 28             5 years
# 29             4 years
# ...                ...
# 2470           7 years
# 2471         10+ years
# 2472           4 years
# 2473           2 years
# 2474         10+ years
# 2475          < 1 year
# 2476         10+ years
# 2477           6 years
# 2478           4 years
# 2479         10+ years
# 2480           2 years
# 2481           5 years
# 2482         10+ years
# 2483           2 years
# 2484         10+ years
# 2485           6 years
# 2486           3 years
# 2487           2 years
# 2488           6 years
# 2489         10+ years
# 2490           3 years
# 2491               NaN
# 2492         10+ years
# 2493         10+ years
# 2494           5 years
# 2495           8 years
# 2496         10+ years
# 2497         10+ years
# 2498           5 years
# 2499         10+ years
#
# [2500 rows x 15 columns]

# %% [markdown]
# The full schema can be found <a href="https://github.com/herrfz/dataanalysis/blob/master/assignment1/Assignment1.pdf">here</a>, but let's use native Pandas methods to also explore the data. Although not specified above, this csv has row headers and the read_csv function implicitly knows this. <br>
#
# Let's take a look at the column names, in a nicely readable way:

# %%
print("Column Names Are:")
print("")

for column_name in loansData.columns.values:
    print(column_name)

print("")
print('Total # of Columns = {}'.format(len(loansData.columns)))
# Out:
# Column Names Are:
#
# CustNUm
# Amount.Requested
# Amount.Funded.By.Investors
# Interest.Rate
# Loan.Length
# Loan.Purpose
# Debt.To.Income.Ratio
# State
# Home.Ownership
# Monthly.Income
# FICO.Range
# Open.CREDIT.Lines
# Revolving.CREDIT.Balance
# Inquiries.in.the.Last.6.Months
# Employment.Length
#
# Total # of Columns = 15

# %%
loansData.columns
# Out:
# Index(['CustNUm', 'Amount.Requested', 'Amount.Funded.By.Investors',
#        'Interest.Rate', 'Loan.Length', 'Loan.Purpose', 'Debt.To.Income.Ratio',
#        'State', 'Home.Ownership', 'Monthly.Income', 'FICO.Range',
#        'Open.CREDIT.Lines', 'Revolving.CREDIT.Balance',
#        'Inquiries.in.the.Last.6.Months', 'Employment.Length'],
#       dtype='object')

# %% [markdown]
# It is oftentimes helpful to take a quick glance at the first few records (when possible). This is an easy way to discover basic data flaws (i.e., all nulls, misaligned fields, etc.). We can do this in Pandas very easily.

# %%
loansData.head().transpose() #We transpose it so it will fit in the display window
# Out:
#                                                  0                   1  \
# CustNUm                                      81174               99592
# Amount.Requested                             20000               19200
# Amount.Funded.By.Investors                   20000               19200
# Interest.Rate                                8.90%              12.12%
# Loan.Length                              36 months           36 months
# Loan.Purpose                    debt_consolidation  debt_consolidation
# Debt.To.Income.Ratio                        14.90%              28.36%
# State                                           SC                  TX
# Home.Ownership                            MORTGAGE            MORTGAGE
# Monthly.Income                             6541.67             4583.33
# FICO.Range                                 735-739             715-719
# Open.CREDIT.Lines                               14                  12
# Revolving.CREDIT.Balance                     14272               11140
# Inquiries.in.the.Last.6.Months                   2                   1
# Employment.Length                         < 1 year             2 years
#
#                                                  2                   3  \
# CustNUm                                      80059               15825
# Amount.Requested                             35000               10000
# Amount.Funded.By.Investors                   35000                9975
# Interest.Rate                               21.98%               9.99%
# Loan.Length                              60 months           36 months
# Loan.Purpose                    debt_consolidation  debt_consolidation
# Debt.To.Income.Ratio                        23.81%              14.30%
# State                                           CA                  KS
# Home.Ownership                            MORTGAGE            MORTGAGE
# Monthly.Income                               11500             3833.33
# FICO.Range                                 690-694             695-699
# Open.CREDIT.Lines                               14                  10
# Revolving.CREDIT.Balance                     21977                9346
# Inquiries.in.the.Last.6.Months                   1                   0
# Employment.Length                          2 years             5 years
#
#                                           4
# CustNUm                               33182
# Amount.Requested                      12000
# Amount.Funded.By.Investors            12000
# Interest.Rate                        11.71%
# Loan.Length                       36 months
# Loan.Purpose                    credit_card
# Debt.To.Income.Ratio                 18.78%
# State                                    NJ
# Home.Ownership                         RENT
# Monthly.Income                         3195
# FICO.Range                          695-699
# Open.CREDIT.Lines                        11
# Revolving.CREDIT.Balance              14469
# Inquiries.in.the.Last.6.Months            0
# Employment.Length                   9 years

# %% [markdown]
# Next, let's run a quick line to get summary statistics of the numeric fields.

# %%
loansData.describe().transpose()
# Out:
#                                  count          mean           std      min  \
# CustNUm                         2500.0  51631.597200  30053.345508    10.00
# Amount.Requested                2500.0  12406.500000   7801.544872  1000.00
# Amount.Funded.By.Investors      2500.0  12001.573236   7745.320754    -0.01
# Monthly.Income                  2499.0   5688.931321   3963.118185   588.50
# Open.CREDIT.Lines               2498.0     10.075661      4.508644     2.00
# Revolving.CREDIT.Balance        2498.0  15244.559648  18308.549795     0.00
# Inquiries.in.the.Last.6.Months  2498.0      0.906325      1.231036     0.00
#
#                                      25%      50%       75%       max
# CustNUm                         26523.00  50653.0  77580.50  104202.0
# Amount.Requested                 6000.00  10000.0  17000.00   35000.0
# Amount.Funded.By.Investors       6000.00  10000.0  16000.00   35000.0
# Monthly.Income                   3500.00   5000.0   6800.00  102750.0
# Open.CREDIT.Lines                   7.00      9.0     13.00      38.0
# Revolving.CREDIT.Balance         5585.75  10962.0  18888.75  270800.0
# Inquiries.in.the.Last.6.Months      0.00      0.0      1.00       9.0

# %%
df = pd.DataFrame({'friendname': ['bob', 'fred', 'sally'], 'height': [1,4,10]})

# %%
df
# Out:
#   friendname  height
# 0        bob       1
# 1       fred       4
# 2      sally      10

# %%
df.loc[12:'height']
# Out:
# Empty DataFrame
# Columns: [friendname, height]
# Index: []

# %%
df.loc[:,'height']
# Out:
# 0     1
# 1     4
# 2    10
# Name: height, dtype: int64

# %%
df.loc[:,['friendname', 'height']]
# Out:
#   friendname  height
# 0        bob       1
# 1       fred       4
# 2      sally      10

# %% [markdown]
# Let's now focus on a single column, 'Monthly.Income.' First things first, let's display the first five records of just this field.

# %%
#Student input line here

# %% [markdown]
# Let's try and understand the distribution of this field. We can do this using the hist() method and matplotlib.

# %%
#plt.figure()
#hist_inc = loansData['Monthly.Income'].hist()
#plt.title('Histogram of Monthly Income')
#plt.show()

# %% [markdown]
# How would you characterize the shape of this distribution? Is there anything we can do to the income variable to make the distribution more bell curved? Let's create a new column in the dataframe called 'Monthly.LogIncome' and print a histogram of it. What might be some advantages of making such a transformation?
# <br>

# %%
#Student: Add a new column Monthly.LogIncome to the dataset that is the log of the Monthly.Income columne

# %%
#Now look at the distribution
plt.figure()
h = loansData['Monthly.LogIncome'].hist()
plt.title('Histogram of Log(Monthly Income)')
plt.show()

# %% [markdown]
# Now let's answer some questions about the data.
#
# <b>Q1: What is the cardinality (i.e., # of distinct values) for 'Interest.Rate' and 'FICO.Range'</b>

# %%
#Student input code here - hint, the 'describe()' method returns a useful dataframe

# %% [markdown]
# <b>Q2: What data type did Pandas set fo Interest.Rate? Can we create a new field which is stored as a float?</b>

# %%
#Student input code here - show the field type

# %% [markdown]
# In the cell below, create a new field 'Interest.Rate.Num' where 'Interest.Rate' is converted to a float. Hint: this can be done in one line using the .str assessor, strip and astype methods.

# %%
#Student input code here - convert field to a float using the '.str' assessor

# %% [markdown]
# <b>Q3: Can we get a sense of the relationship between monthly income and interest rate? Use the scatter() function from Matplotlib.</b>

# %%
#Student input line here

# %% [markdown]
# Given the skewed distribution of Income, is this chart visually helpful? Let's try the Log of income instead.

# %%
#Student input code here

# %% [markdown]
# <b>Q4: What is the average interest rate for each FICO range?</b> <br>
# Hint: use the groupby() method in Pandas.

# %%
#Student input code here
fico_grp =

# %%
#fico_grp
